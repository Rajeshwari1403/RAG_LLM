# %% [markdown]
# ### Data Ingesion

# %% [markdown]
# ###Document Structure

# %%
from langchain_core.documents import Document

# %%
doc=Document(
  page_content="This is the main text content for RAG",
  metadata={
    "source": "user.txt",
    "pages": 1,
    "author": "Rathu",
    "date_created": "2026-01-01"
  }
)

# %%
# Create a txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/py_intro.txt": """Python is a high-level, interpreted programming language known for its clear syntax and readability. Created by Guido van Rossum and first released in 1991, Python's design philosophy emphasizes code readability with its notable use of significant whitespace. It allows programmers to express concepts in fewer lines of code than might be possible in languages such as C++ or Java.

The language provides constructs intended to enable clear programs on both a small and large scale. Python features a dynamic type system and automatic memory management and supports multiple programming paradigms, including object-oriented, imperative, functional, and procedural styles. It possesses a large and comprehensive standard library, which is often cited as one of Python's greatest strengths, providing tools suited to many tasks.

In the modern technology landscape, Python has become the dominant language for data science, machine learning, and artificial intelligence development. This dominance is driven by a powerful ecosystem of third-party libraries such as NumPy for numerical computation, Pandas for data analysis, and advanced frameworks like LangChain for building applications powered by Large Language Models (LLMs). Its simplicity makes it an ideal choice for automating tasks, parsing documents, and managing complex data ingestion workflows.""",

    "../data/text_files/new_ml_file.txt": """Key features of Python include its cross-platform compatibility, meaning code written on Windows can run seamlessly on macOS or Linux systems without modifications. It is an interpreted language, which means code is executed line-by-line, making debugging highly intuitive and interactive for developers.

Python's extensive open-source package index, known as PyPI (Python Package Index), contains hundreds of thousands of external libraries that extend its core functionality. This allows developers to quickly integrate pre-built components for web scraping, database connectivity, and cloud computing APIs without reinventing the wheel. Additionally, its strong community support ensures continuous updates, optimization, and documentation for modern software engineering standards."""
}

for filepath,content in sample_text.items():
  with open(filepath, 'w', encoding="utf-8") as f:
    f.write(content)

print("Sample txt created!!!")
# Out:
# Sample txt created!!!

# %%
# Read the Text using TextLoader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/py_intro.txt", encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/py_intro.txt'}, page_content="Python is a high-level, interpreted programming language known for its clear syntax and readability. Created by Guido van Rossum and first released in 1991, Python's design philosophy emphasizes code readability with its notable use of significant whitespace. It allows programmers to express concepts in fewer lines of code than might be possible in languages such as C++ or Java.\n\nThe language provides constructs intended to enable clear programs on both a small and large scale. Python features a dynamic type system and automatic memory management and supports multiple programming paradigms, including object-oriented, imperative, functional, and procedural styles. It possesses a large and comprehensive standard library, which is often cited as one of Python's greatest strengths, providing tools suited to many tasks.\n\nIn the modern technology landscape, Python has become the dominant language for data s
# ...

# %%
# Another Way
# Directory loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader=DirectoryLoader(
  "../data/text_files",
  glob="**/*.txt",
  loader_cls=TextLoader,
  loader_kwargs={ 'encoding': 'utf-8' },
  show_progress=False
)

documents=dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\new_ml_file.txt'}, page_content="Key features of Python include its cross-platform compatibility, meaning code written on Windows can run seamlessly on macOS or Linux systems without modifications. It is an interpreted language, which means code is executed line-by-line, making debugging highly intuitive and interactive for developers.\n\nPython's extensive open-source package index, known as PyPI (Python Package Index), contains hundreds of thousands of external libraries that extend its core functionality. This allows developers to quickly integrate pre-built components for web scraping, database connectivity, and cloud computing APIs without reinventing the wheel. Additionally, its strong community support ensures continuous updates, optimization, and documentation for modern software engineering standards."), Document(metadata={'source': '..\\data\\text_files\\py_intro.txt'}, page_content="Python is a high-level, interpreted pr
# ...

# %%
# Another Way
# Directory loader, But here for reading PDF also

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader=DirectoryLoader(
  "../data/pdf",
  glob="**/*.pdf",
  loader_cls=PyMuPDFLoader,
  show_progress=False
)

"""pdf_documents=dir_loader.load()
for doc in pdf_documents:
    print(doc.page_content)
    print("-" * 50)"""

pdf_documents=dir_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': 'PyFPDF 1.7.2 http://pyfpdf.googlecode.com/', 'creator': '', 'creationdate': 'D:20250507163210', 'source': '..\\data\\pdf\\SQL_1.pdf', 'file_path': '..\\data\\pdf\\SQL_1.pdf', 'total_pages': 2, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20250507163210', 'page': 0}, page_content='1. What is SQL?\nSQL (Structured Query Language) is a standard language used to store, retrieve, and manipulate\ndata in relational databases.\n2. What is the difference between INNER JOIN and LEFT JOIN?\n- INNER JOIN returns only matching rows from both tables.\n- LEFT JOIN returns all rows from the left table, and matched rows from the right table (or NULLs if\nno match).\n3. What is the difference between ON and WHERE clause in SQL joins?\n- ON is used to define the join condition between two tables.\n- WHERE is used to filter the final result set after the join is performed.\
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
